# %% [markdown]
# # Vector and Matrix Implementation with Pandas

# %%
from pathlib import Path
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pylab as plt
# %matplotlib inline

# %%
# load data from the data folder
# make the first column index
mydata = pd.read_csv('C:/Users/simon/Downloads/Data-Epidemiologiske-Rapport-01032021-m4m8/Region_summary.csv', sep = ';', header = 0,  thousands='.', decimal=',')

# %%
mydata
# Out:
#             Region  Testede  Positive  Indlagt_total  Døde
# 0      Hovedstaden  1445845    100366           6181  1266
# 1         Sjælland   590646     29402           2165   377
# 2       Syddanmark   873363     28503           1384   204
# 3      Midtjylland   958983     37116           1827   339
# 4      Nordjylland   465939     14450            800   177
# 5  I alt i Danmark  4334776    209837          12357  2363

# %%
mydata.shape
# Out:
# (6, 5)

# %%
mydata.describe()
# Out:
#             Testede       Positive  Indlagt_total         Døde
# count  6.000000e+00       6.000000       6.000000     6.000000
# mean   1.444925e+06   69945.666667    4119.000000   787.666667
# std    1.456178e+06   74851.615054    4465.061119   871.092111
# min    4.659390e+05   14450.000000     800.000000   177.000000
# 25%    6.613252e+05   28727.750000    1494.750000   237.750000
# 50%    9.161730e+05   33259.000000    1996.000000   358.000000
# 75%    1.324130e+06   84553.500000    5177.000000  1043.750000
# max    4.334776e+06  209837.000000   12357.000000  2363.000000

# %%
mydata = mydata[:5]

# %%
mydata
# Out:
#         Region  Testede  Positive  Indlagt_total  Døde
# 0  Hovedstaden  1445845    100366           6181  1266
# 1     Sjælland   590646     29402           2165   377
# 2   Syddanmark   873363     28503           1384   204
# 3  Midtjylland   958983     37116           1827   339
# 4  Nordjylland   465939     14450            800   177

# %%
list(mydata)
# Out:
# ['Region', 'Testede', 'Positive', 'Indlagt_total', 'Døde']

# %%
mydata.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
mydata.dtypes
# Out:
# Region           object
# Testede           int64
# Positive          int64
# Indlagt_total     int64
# Døde              int64
# dtype: object

# %%
mydata.values
# Out:
# array([['Hovedstaden', 1445845, 100366, 6181, 1266],
#        ['Sjælland', 590646, 29402, 2165, 377],
#        ['Syddanmark', 873363, 28503, 1384, 204],
#        ['Midtjylland', 958983, 37116, 1827, 339],
#        ['Nordjylland', 465939, 14450, 800, 177]], dtype=object)

# %%
# dn = mydata.to_numpy()

# %%
plt.figure()
sns.relplot(data=mydata, x=mydata['Testede'], y=mydata['Positive'], hue=mydata["Region"])
plt.show(sns)

# %%
from pandas.plotting import parallel_coordinates
plt.figure();
parallel_coordinates(mydata, "Region");

# %%
mydata.set_index("Region")
# Out:
#              Testede  Positive  Indlagt_total  Døde
# Region
# Hovedstaden  1445845    100366           6181  1266
# Sjælland      590646     29402           2165   377
# Syddanmark    873363     28503           1384   204
# Midtjylland   958983     37116           1827   339
# Nordjylland   465939     14450            800   177

# %%
mydata.plot.scatter(x="Region", y="Positive", s=mydata['Døde']);

# %% [markdown]
# __Exercise__: Explore and plot in similar mode the municipality data.

# %%
mydata = pd.read_csv('C:/Users/simon/Downloads/Data-Epidemiologiske-Rapport-01032021-m4m8/Municipality_test_pos.csv', sep = ';', header = 0,  thousands='.', decimal=',')

# %%
mydata
# Out:
#     Kommune_(id) Kommune_(navn)  Antal_testede  Antal_bekræftede_COVID-19  \
# 0            101      København         506048                      38304
# 1            147  Frederiksberg          82348                       5794
# 2            151       Ballerup          39627                       2849
# 3            153        Brøndby          28046                       2715
# 4            155         Dragør          11212                        665
# ..           ...            ...            ...                        ...
# 94           840         Rebild          20907                        640
# 95           846  Mariagerfjord          28605                        915
# 96           849     Jammerbugt          32492                        924
# 97           851        Aalborg         162796                       6218
# 98           860       Hjørring          55245                       1314
#
#     Befolkningstal  Kumulativ_incidens_(per_100000)
# ...

# %%
plt.figure()
sns.relplot(data=mydata, x=mydata['Antal_testede'], y=mydata['Antal_bekræftede_COVID-19'], hue=mydata["Kommune_(navn)"])
plt.show(sns)

# %%
from pandas.plotting import parallel_coordinates
plt.figure();
parallel_coordinates(mydata, "Kommune_(navn)");

# %%
mydata.set_index("Kommune_(navn)")
# Out:
#                 Kommune_(id)  Antal_testede  Antal_bekræftede_COVID-19  \
# Kommune_(navn)
# København                101         506048                      38304
# Frederiksberg            147          82348                       5794
# Ballerup                 151          39627                       2849
# Brøndby                  153          28046                       2715
# Dragør                   155          11212                        665
# ...                      ...            ...                        ...
# Rebild                   840          20907                        640
# Mariagerfjord            846          28605                        915
# Jammerbugt               849          32492                        924
# Aalborg                  851         162796                       6218
# Hjørring                 860          55245                       1314
#
#                 Befolkningstal  Kumulativ_incidens_(per_100000)
# Kommune_(navn)
# ...

# %%
mydata.plot.scatter(x="Kommune_(navn)", y="Antal_testede", s=mydata['Antal_bekræftede_COVID-19']);
